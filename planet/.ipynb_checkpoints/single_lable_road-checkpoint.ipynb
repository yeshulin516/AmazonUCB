# %%
import sys
import os
import subprocess
from six import string_types
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import scipy
from skimage import io
from scipy import ndimage
from IPython.display import display
import cv2
from keras.models import Sequential
from keras.layers import Input, Dropout, Flatten, Convolution2D, MaxPooling2D, Dense, Activation
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.utils import np_utils
from keras import regularizers
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
PLANET_KAGGLE_ROOT = os.path.abspath("/Users/sunchenxi/Desktop/lab/kaggle/amazon/")
PLANET_KAGGLE_JPEG_DIR = os.path.join(PLANET_KAGGLE_ROOT, 'train-jpg')
PLANET_KAGGLE_LABEL_CSV = os.path.join(PLANET_KAGGLE_ROOT, 'train_v2.csv')
assert os.path.exists(PLANET_KAGGLE_ROOT)
assert os.path.exists(PLANET_KAGGLE_JPEG_DIR)
assert os.path.exists(PLANET_KAGGLE_LABEL_CSV)

# %%
#读取train set标签
labels_df = pd.read_csv(PLANET_KAGGLE_LABEL_CSV)
label_list = []
for tag_str in labels_df.tags.values:
    labels = tag_str.split(' ')
    for label in labels:
        if label not in label_list:
            label_list.append(label)
for label in label_list:
    labels_df[label] = labels_df['tags'].apply(lambda x: 1 if label in x.split(' ') else 0)

# %%
#获取含有tags标签的n张图片
def sample_images(tags, n=None):
    """Randomly sample n images with the specified tags."""
    condition = True
    if isinstance(tags, string_types): #tag是否是string类型
        raise ValueError("Pass a list of tags, not a single tag.")
    for tag in tags:
        condition = condition & labels_df[tag] == 1
    if n is not None:
        return labels_df[condition].sample(n)
    else:
        return labels_df[condition]
#获取不含含有tags标签的n张图片
def not_sample_images(tags, n=None):
    """Randomly sample n images with the specified tags."""
    condition = True
    if isinstance(tags, string_types): #tag是否是string类型
        raise ValueError("Pass a list of tags, not a single tag.")
    for tag in tags:
        condition = condition & labels_df[tag] == 0
    if n is not None:
        return labels_df[condition].sample(n)
    else:
        return labels_df[condition]
def load_image(filename):
    '''Look through the directory tree to find the image you specified
    (e.g. train_10.tif vs. train_10.jpg)'''
    for dirname in os.listdir(PLANET_KAGGLE_ROOT):
        path = os.path.abspath(os.path.join(PLANET_KAGGLE_ROOT, dirname, filename))
        if os.path.exists(path):
            print('Found image {}'.format(path))
            return io.imread(path)
    print('Load failed: could not find image {}'.format(path))
 
 #将图片在数组中的位置变成名称
def sample_to_fname(sample_df, row_idx, suffix='jpg'):
    '''Given a dataframe of sampled images, get the
    corresponding filename.'''
    fname = sample_df.get_value(sample_df.index[row_idx], 'image_name')
    return '{}.{}'.format(fname, suffix)

# %% [markdown]
# ### 获取含有road的图片,变成三通道

# %%
n=0
for i in range(len(labels_df)):
    if(labels_df['road'][i]==1):
        n=n+1
fname=[0]*n
s = sample_images(['road'], n=n)
for i in range(n):
    fname[i]= sample_to_fname(s, i)#获得了文件名
road_img=[mpimg.imread(PLANET_KAGGLE_ROOT+'/train-jpg/'+ img) for img in fname[:300]]

# %%
road_img3=[]
for i in range(len(road_img)):
    for j in range (len(road_img[i])):
        for k in range(len(road_img[i][j])):
            road_img2=road_img[i][j][k][:3]
            road_img3.append(road_img2)
road_img3=np.asarray(road_img3).reshape(300,256,256,3)

# %% [markdown]
# ### 获取不含road的图片

# %%
n=0
for i in range(len(labels_df)):
    if(labels_df['road'][i]==0):
        n=n+1
fname_not=[0]*n
s = not_sample_images(['road'], n=n)
for i in range(n):
    fname_not[i]= sample_to_fname(s, i)#获得了文件名
not_road_img=[mpimg.imread(PLANET_KAGGLE_ROOT+'/train-jpg/'+ img) for img in fname_not[:300]]

# %%
not_road_img3=[]
for i in range(len(not_road_img)):
    for j in range (len(not_road_img[i])):
        for k in range(len(not_road_img[i][j])):
            not_road_img2=not_road_img[i][j][k][:3]
            not_road_img3.append(not_road_img2)
not_road_img3=np.asarray(not_road_img3).reshape(300,256,256,3)

# %% [markdown]
# ### 训练的图片和标签

# %% [markdown]
# #### 一定要用vstack

# %%
images=np.vstack((road_img3,not_road_img3))
labels=[1,0]*300+[0,1]*300
resized_images = [np.reshape(cv2.resize(img,(64,64),interpolation=cv2.INTER_AREA), [1,64,64,3]) for img in images]

# %%
train_size = int(len(resized_images)*0.9)
train_x = np.vstack(resized_images[:train_size])
test_x = resized_images[train_size:]
train_y = np.vstack(labels[:train_size])
test_y = labels[train_size:]

# %% [markdown]
# ### 四通道的图片

# %%
img=road_img[:500]+not_road_img[:500]
labels=[1,0]*500+[0,1]*500
resized_images2 = [np.reshape(cv2.resize(img,(64,64),interpolation=cv2.INTER_AREA), [1,64,64,4]) for img in img]
train_size = int(len(resized_images2))
train_x2 = np.vstack(resized_images2[:train_size])
test_x2= resized_images2[train_size:]
train_y2 = np.vstack(labels[:train_size])
test_y2 = labels[train_size:]

# %%
op = RMSprop(lr=0.0001)
ob = 'binary_crossentropy'
def Cnet():
    
    model = Sequential()

    model.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=(64, 64, 3), activation='relu'))
    model.add(Convolution2D(32, 3, 3, border_mode='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3)))

    model.add(Convolution2D(64, 4, 4, border_mode='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    

    
    model.add(Convolution2D(128, 4, 4, border_mode='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    

    model.add(Flatten())
    model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(0.3)))
    
    model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(0.3)))

    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    model.compile(loss=ob, optimizer=op, metrics=['accuracy'])
    return model


model = Cnet()


model = Cnet()
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.val_losses = []
        
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))

history = LossHistory()
model.fit(train_x, train_y, batch_size=32, epochs=64,validation_split=0.25, verbose=1, shuffle=True, callbacks=[history])
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=(64, 64, 3...)`
#   import sys
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", activation="relu")`
#
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (4, 4), padding="same", activation="relu")`
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (4, 4), padding="same", activation="relu")`
#   app.launch_new_instance()
# Train on 405 samples, validate on 135 samples
# Epoch 1/64
# 405/405 [==============================] - 9s - loss: 176.3699 - acc: 0.4988 - val_loss: 171.0487 - val_acc: 0.5185
# Epoch 2/64
# 405/405 [==============================] - 8s - loss: 168.2638 - acc: 0.5432 - val_loss: 164.8248 - val_acc: 0.4963
# Epoch 3/64
# 405/405 [==============================] - 8s - loss: 162.1033 - acc: 0.5753 - val_loss: 158.8416 - val_acc: 0.4963
# Epoch 4/64
# 405/405 [==============================] - 7s - loss: 156.1716 - acc: 0.5333 - val_loss: 152.9704 - val_acc: 0.5185
# Epoch 5/64
# 405/405 [==============================] - 8s - loss: 150.3884 - acc: 0.5556 - val_loss: 147.1973 - val_acc: 0.5111
# Epoch 6/64
# 405/405 [==============================] - 7s - loss: 144.7113 - acc: 0.5481 - val_loss: 141.6311 - val_acc: 0.4963
# Epoch 7/64
# 405/405 [==============================] - 8s - loss: 139.1533 - acc: 0.5827 - val_loss: 136.1411 - val_acc: 0.5185
# Epoch 8/64
# 405/405 [==============================] - 8s - loss: 133.6224 - acc: 0.6123 - val_loss: 130.7622 - val_acc: 0.4963
# Epoch 9/64
# 405/405 [==============================] - 8s - loss: 128.2154 - acc: 0.5679 - val_loss: 125.4207 - val_acc: 0.4963
# Epoch 10/64
# 405/405 [==============================] - 9s - loss: 122.9314 - acc: 0.6049 - val_loss: 120.1416 - val_acc: 0.5111
# Epoch 11/64
# 405/405 [==============================] - 9s - loss: 117.7328 - acc: 0.6741 - val_loss: 115.0399 - val_acc: 0.5111
# Epoch 12/64
# 405/405 [==============================] - 8s - loss: 112.7319 - acc: 0.6296 - val_loss: 110.1421 - val_acc: 0.5185
# Epoch 13/64
# 405/405 [==============================] - 8s - loss: 107.8675 - acc: 0.7012 - val_loss: 105.3833 - val_acc: 0.4889
# Epoch 14/64
# 405/405 [==============================] - 8s - loss: 103.1714 - acc: 0.6840 - val_loss: 100.7824 - val_acc: 0.4815
# Epoch 15/64
# 405/405 [==============================] - 7s - loss: 98.6199 - acc: 0.6494 - val_loss: 96.2644 - val_acc: 0.4741
# Epoch 16/64
# 405/405 [==============================] - 7s - loss: 94.1666 - acc: 0.6444 - val_loss: 91.9478 - val_acc: 0.5037
# Epoch 17/64
# 405/405 [==============================] - 7s - loss: 89.8655 - acc: 0.7012 - val_loss: 87.6936 - val_acc: 0.4519
# Epoch 18/64
# 405/405 [==============================] - 8s - loss: 85.6996 - acc: 0.7012 - val_loss: 83.6794 - val_acc: 0.4889
# Epoch 19/64
# 405/405 [==============================] - 8s - loss: 81.6975 - acc: 0.6765 - val_loss: 79.7216 - val_acc: 0.5037
# Epoch 20/64
# 405/405 [==============================] - 8s - loss: 77.8040 - acc: 0.7185 - val_loss: 75.8688 - val_acc: 0.4519
# Epoch 21/64
# 405/405 [==============================] - 8s - loss: 74.0566 - acc: 0.6889 - val_loss: 72.1909 - val_acc: 0.4815
# Epoch 22/64
# 405/405 [==============================] - 8s - loss: 70.4045 - acc: 0.7383 - val_loss: 68.6459 - val_acc: 0.5185
# Epoch 23/64
# 405/405 [==============================] - 8s - loss: 66.8869 - acc: 0.7605 - val_loss: 65.2095 - val_acc: 0.4889
# Epoch 24/64
# 405/405 [==============================] - 8s - loss: 63.4935 - acc: 0.7012 - val_loss: 61.8914 - val_acc: 0.5259
# Epoch 25/64
# 405/405 [==============================] - 7s - loss: 60.2465 - acc: 0.7457 - val_loss: 58.6928 - val_acc: 0.4889
# Epoch 26/64
# 405/405 [==============================] - 7s - loss: 57.1010 - acc: 0.7679 - val_loss: 55.6577 - val_acc: 0.5037
# Epoch 27/64
# 405/405 [==============================] - 7s - loss: 54.0784 - acc: 0.7259 - val_loss: 52.7242 - val_acc: 0.5037
# Epoch 28/64
# 405/405 [==============================] - 7s - loss: 51.1614 - acc: 0.7654 - val_loss: 49.8538 - val_acc: 0.5185
# Epoch 29/64
# 405/405 [==============================] - 7s - loss: 48.3795 - acc: 0.7284 - val_loss: 47.0835 - val_acc: 0.4741
# Epoch 30/64
# 405/405 [==============================] - 7s - loss: 45.6901 - acc: 0.7975 - val_loss: 44.5595 - val_acc: 0.4963
# Epoch 31/64
# 405/405 [==============================] - 7s - loss: 43.1738 - acc: 0.7654 - val_loss: 42.0318 - val_acc: 0.4963
# Epoch 32/64
# 405/405 [==============================] - 7s - loss: 40.7982 - acc: 0.7309 - val_loss: 39.6975 - val_acc: 0.4889
# Epoch 33/64
# 405/405 [==============================] - 7s - loss: 38.4414 - acc: 0.7877 - val_loss: 37.4791 - val_acc: 0.5037
# Epoch 34/64
# 405/405 [==============================] - 7s - loss: 36.2103 - acc: 0.7728 - val_loss: 35.3435 - val_acc: 0.4963
# Epoch 35/64
# 405/405 [==============================] - 8s - loss: 34.0664 - acc: 0.7877 - val_loss: 33.1645 - val_acc: 0.5259
# Epoch 36/64
# 405/405 [==============================] - 7s - loss: 31.9929 - acc: 0.7951 - val_loss: 31.1870 - val_acc: 0.5037
# Epoch 37/64
# 405/405 [==============================] - 7s - loss: 30.0763 - acc: 0.7481 - val_loss: 29.3078 - val_acc: 0.5259
# Epoch 38/64
# 405/405 [==============================] - 7s - loss: 28.2334 - acc: 0.7679 - val_loss: 27.5163 - val_acc: 0.5333
# Epoch 39/64
# 405/405 [==============================] - 7s - loss: 26.4788 - acc: 0.7802 - val_loss: 25.8046 - val_acc: 0.5333
# Epoch 40/64
# 405/405 [==============================] - 7s - loss: 24.7633 - acc: 0.8272 - val_loss: 24.1584 - val_acc: 0.4889
# Epoch 41/64
# 405/405 [==============================] - 7s - loss: 23.1902 - acc: 0.7580 - val_loss: 22.6099 - val_acc: 0.4741
# Epoch 42/64
# 405/405 [==============================] - 7s - loss: 21.6462 - acc: 0.8148 - val_loss: 21.1694 - val_acc: 0.5185
# Epoch 43/64
# 405/405 [==============================] - 8s - loss: 20.2419 - acc: 0.8025 - val_loss: 19.7496 - val_acc: 0.5333
# Epoch 44/64
# 405/405 [==============================] - 7s - loss: 18.8577 - acc: 0.8148 - val_loss: 18.5961 - val_acc: 0.5111
# Epoch 45/64
# 405/405 [==============================] - 7s - loss: 17.6258 - acc: 0.7901 - val_loss: 17.2568 - val_acc: 0.5333
# Epoch 46/64
# 405/405 [==============================] - 7s - loss: 16.3582 - acc: 0.8642 - val_loss: 16.0541 - val_acc: 0.4741
# Epoch 47/64
# 405/405 [==============================] - 8s - loss: 15.2081 - acc: 0.8123 - val_loss: 14.9876 - val_acc: 0.5037
# Epoch 48/64
# 405/405 [==============================] - 8s - loss: 14.1545 - acc: 0.8025 - val_loss: 13.9127 - val_acc: 0.4667
# Epoch 49/64
# 405/405 [==============================] - 8s - loss: 13.1510 - acc: 0.8173 - val_loss: 12.9705 - val_acc: 0.4444
# Epoch 50/64
# 405/405 [==============================] - 8s - loss: 12.2067 - acc: 0.8420 - val_loss: 12.1139 - val_acc: 0.5259
# Epoch 51/64
# 405/405 [==============================] - 7s - loss: 11.3581 - acc: 0.8074 - val_loss: 11.2308 - val_acc: 0.5037
# Epoch 52/64
# 405/405 [==============================] - 7s - loss: 10.5220 - acc: 0.8370 - val_loss: 10.5801 - val_acc: 0.5185
# Epoch 53/64
# 405/405 [==============================] - 7s - loss: 9.7859 - acc: 0.8247 - val_loss: 9.7413 - val_acc: 0.4815
# Epoch 54/64
# 405/405 [==============================] - 7s - loss: 9.0518 - acc: 0.8519 - val_loss: 9.0682 - val_acc: 0.5111
# Epoch 55/64
# 405/405 [==============================] - 7s - loss: 8.3837 - acc: 0.8346 - val_loss: 8.4020 - val_acc: 0.4889
# Epoch 56/64
# 405/405 [==============================] - 7s - loss: 7.7328 - acc: 0.8667 - val_loss: 7.9070 - val_acc: 0.4963
# Epoch 57/64
# 405/405 [==============================] - 7s - loss: 7.1947 - acc: 0.8272 - val_loss: 7.2976 - val_acc: 0.4444
# Epoch 58/64
# 405/405 [==============================] - 7s - loss: 6.6255 - acc: 0.8790 - val_loss: 6.8072 - val_acc: 0.4963
# Epoch 59/64
# 405/405 [==============================] - 8s - loss: 6.1596 - acc: 0.8642 - val_loss: 6.3003 - val_acc: 0.4444
# Epoch 60/64
# 405/405 [==============================] - 7s - loss: 5.6876 - acc: 0.8741 - val_loss: 5.8632 - val_acc: 0.4889
# Epoch 61/64
# 405/405 [==============================] - 7s - loss: 5.2745 - acc: 0.8840 - val_loss: 5.5270 - val_acc: 0.4963
# Epoch 62/64
# 405/405 [==============================] - 8s - loss: 4.8770 - acc: 0.8963 - val_loss: 5.2493 - val_acc: 0.5185
# Epoch 63/64
# 405/405 [==============================] - 8s - loss: 4.5488 - acc: 0.8691 - val_loss: 4.8346 - val_acc: 0.5111
# Epoch 64/64
# 405/405 [==============================] - 7s - loss: 4.2250 - acc: 0.8988 - val_loss: 4.5460 - val_acc: 0.5037

# %%
score = model.evaluate(train_x, train_y, verbose=0)  
print('Test score:', score[0])  
print('Test accuracy:', score[1])
# Out:
# ('Test score:', 4.1745377081411856)
# ('Test accuracy:', 0.78888888910964683)

# %%
loss = history.losses
val_loss = history.val_losses
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('VGG-16 Loss Trend (Underfitting)')
plt.plot(loss[1:], 'blue', label='Training Loss')
plt.plot(val_loss[1:], 'green', label='Validation Loss')
plt.legend()
plt.show()

# %%
n=0
for i in range(0,300):
    a=model.predict(resized_images[i])
    if(a>0.5):
        n+=1  
n2=0
for i in range(300,600):
    a=model.predict(resized_images[i])
    if(a<0.5):
        n2+=1 
acc=(float)(n+n2)/600

# %%
acc
# Out:
# 0.6333333333333333

# %%
img_test=[mpimg.imread(PLANET_KAGGLE_ROOT+'/train-jpg/train_0.jpg')]

# %%
img_test
# Out:
# [array([[[ 97, 112, 105, 255],
#          [ 94, 112, 102, 255],
#          [ 94, 112, 101, 255],
#          ...,
#          [ 97, 112, 103, 255],
#          [ 97, 111, 103, 255],
#          [ 95, 109, 103, 255]],
#
#         [[ 94, 109, 102, 255],
#          [ 92, 109, 100, 255],
#          [ 92, 110, 100, 255],
#          ...,
#          [ 95, 110, 102, 255],
#          [ 95, 109, 103, 255],
#          [ 94, 108, 103, 255]],
#
#         [[ 90, 106, 100, 255],
#          [ 89, 106,  99, 255],
#          [ 90, 108,  99, 255],
#          ...,
#          [ 93, 107, 101, 255],
#          [ 92, 107, 102, 255],
#          [ 91, 107, 102, 255]],
#
#         ...,
#         [[ 93, 111, 108, 255],
#          [ 94, 111, 107, 255],
#          [ 94, 112, 107, 255],
#          ...,
#          [ 90, 110, 106, 255],
#          [ 87, 108, 106, 255],
#          [ 82, 103, 102, 255]],
#
#         [[ 96, 109, 107, 255],
#          [ 95, 110, 107, 255],
#          [ 94, 110, 106, 255],
#          ...,
#          [ 92, 111, 105, 255],
#          [ 89, 108, 105, 255],
#          [ 83, 103, 101, 255]],
#
#         [[ 98, 108, 106, 255],
#          [ 96, 108, 105, 255],
#          [ 94, 108, 105, 255],
#          ...,
#          [ 94, 110, 104, 255],
#          [ 90, 108, 103, 255],
#          [ 83, 102,  98, 255]]], dtype=uint8)]

# %%
img_test3=[]
for i in range(len(img_test)):
    for j in range (len(img_test[i])):
        for k in range(len(img_test[i][j])):
            img_test2=img_test[i][j][k][:3]
            img_test3.append(img_test2)

# %%
img_test3
# Out:
# [array([ 97, 112, 105], dtype=uint8),
#  array([ 94, 112, 102], dtype=uint8),
#  array([ 94, 112, 101], dtype=uint8),
#  array([ 97, 114, 103], dtype=uint8),
#  array([102, 115, 107], dtype=uint8),
#  array([103, 114, 107], dtype=uint8),
#  array([ 98, 110, 102], dtype=uint8),
#  array([ 93, 107,  97], dtype=uint8),
#  array([ 91, 113, 105], dtype=uint8),
#  array([ 94, 112, 104], dtype=uint8),
#  array([ 96, 111, 103], dtype=uint8),
#  array([ 95, 109, 102], dtype=uint8),
#  array([ 92, 108, 102], dtype=uint8),
#  array([ 90, 107, 102], dtype=uint8),
#  array([ 91, 107, 103], dtype=uint8),
#  array([ 93, 107, 103], dtype=uint8),
#  array([ 99, 111, 104], dtype=uint8),
#  array([ 96, 111, 103], dtype=uint8),
#  array([ 90, 110, 102], dtype=uint8),
#  array([ 87, 110, 101], dtype=uint8),
#  array([ 90, 109, 100], dtype=uint8),
#  array([ 93, 108,  99], dtype=uint8),
#  array([ 87, 107,  99], dtype=uint8),
#  array([ 77, 106,  99], dtype=uint8),
#  array([ 84, 102, 101], dtype=uint8),
#  array([ 90, 109, 104], dtype=uint8),
#  array([ 98, 118, 109], dtype=uint8),
#  array([105, 121, 110], dtype=uint8),
#  array([108, 118, 108], dtype=uint8),
#  array([105, 112, 105], dtype=uint8),
#  array([ 97, 109, 102], dtype=uint8),
#  array([ 91, 107, 101], dtype=uint8),
#  array([ 96, 110, 108], dtype=uint8),
#  array([ 95, 111, 103], dtype=uint8),
#  array([ 97, 113, 103], dtype=uint8),
#  array([102, 115, 107], dtype=uint8),
#  array([101, 115, 109], dtype=uint8),
#  array([ 94, 113, 105], dtype=uint8),
#  array([ 90, 111, 100], dtype=uint8),
#  array([ 90, 110,  99], dtype=uint8),
#  array([ 90, 110, 104], dtype=uint8),
#  array([ 89, 112, 104], dtype=uint8),
#  array([ 91, 113, 105], dtype=uint8),
#  array([ 93, 114, 105], dtype=uint8),
#  array([ 91, 113, 105], dtype=uint8),
#  array([ 87, 111, 104], dtype=uint8),
#  array([ 87, 108, 103], dtype=uint8),
#  array([ 91, 107, 102], dtype=uint8),
#  array([ 90, 108, 101], dtype=uint8),
#  array([ 91, 110, 105], dtype=uint8),
#  array([ 94, 111, 109], dtype=uint8),
#  array([ 98, 111, 107], dtype=uint8),
#  array([ 96, 110, 102], dtype=uint8),
#  array([ 92, 110, 100], dtype=uint8),
#  array([ 93, 112, 102], dtype=uint8),
#  array([ 98, 114, 105], dtype=uint8),
#  array([ 93, 114, 105], dtype=uint8),
#  array([ 93, 112, 105], dtype=uint8),
#  array([ 91, 109, 105], dtype=uint8),
#  array([ 91, 108, 104], dtype=uint8),
#  array([ 90, 108, 103], dtype=uint8),
#  array([ 90, 108, 101], dtype=uint8),
#  array([ 90, 107, 100], dtype=uint8),
#  array([ 90, 106,  99], dtype=uint8),
#  array([ 96, 112, 105], dtype=uint8),
#  array([ 97, 111, 106], dtype=uint8),
#  array([ 97, 109, 105], dtype=uint8),
#  array([ 95, 108, 103], dtype=uint8),
#  array([ 91, 107, 101], dtype=uint8),
#  array([ 89, 108, 101], dtype=uint8),
#  array([ 89, 109, 104], dtype=uint8),
#  array([ 89, 109, 106], dtype=uint8),
#  array([ 95, 112, 108], dtype=uint8),
#  array([ 96, 111, 107], dtype=uint8),
#  array([ 96, 111, 105], dtype=uint8),
#  array([ 97, 110, 104], dtype=uint8),
#  array([ 96, 110, 104], dtype=uint8),
#  array([ 96, 110, 105], dtype=uint8),
#  array([ 95, 111, 106], dtype=uint8),
#  array([ 95, 111, 107], dtype=uint8),
#  array([ 91, 108, 100], dtype=uint8),
#  array([ 89, 109, 102], dtype=uint8),
#  array([ 88, 111, 103], dtype=uint8),
#  array([ 89, 111, 103], dtype=uint8),
#  array([ 91, 109, 102], dtype=uint8),
#  array([ 92, 109, 102], dtype=uint8),
#  array([ 95, 111, 104], dtype=uint8),
#  array([ 99, 112, 105], dtype=uint8),
#  array([ 97, 110, 105], dtype=uint8),
#  array([ 96, 111, 106], dtype=uint8),
#  array([ 96, 114, 107], dtype=uint8),
#  array([ 98, 116, 107], dtype=uint8),
#  array([101, 116, 105], dtype=uint8),
#  array([102, 115, 105], dtype=uint8),
#  array([ 99, 113, 106], dtype=uint8),
#  array([ 96, 112, 107], dtype=uint8),
#  array([ 91, 111, 104], dtype=uint8),
#  array([ 94, 110, 103], dtype=uint8),
#  array([ 96, 109, 102], dtype=uint8),
#  array([ 94, 108, 101], dtype=uint8),
#  array([ 90, 108, 102], dtype=uint8),
#  array([ 89, 108, 103], dtype=uint8),
#  array([ 93, 108, 105], dtype=uint8),
#  array([ 97, 109, 106], dtype=uint8),
#  array([ 93, 107, 101], dtype=uint8),
#  array([ 93, 108, 101], dtype=uint8),
#  array([ 93, 111, 102], dtype=uint8),
#  array([ 95, 113, 105], dtype=uint8),
#  array([ 99, 115, 109], dtype=uint8),
#  array([101, 115, 111], dtype=uint8),
#  array([102, 114, 110], dtype=uint8),
#  array([101, 114, 109], dtype=uint8),
#  array([ 90, 109, 104], dtype=uint8),
#  array([ 92, 107, 104], dtype=uint8),
#  array([ 91, 106, 104], dtype=uint8),
#  array([ 90, 106, 104], dtype=uint8),
#  array([ 91, 109, 104], dtype=uint8),
#  array([ 94, 111, 104], dtype=uint8),
#  array([ 92, 112, 104], dtype=uint8),
#  array([ 87, 112, 104], dtype=uint8),
#  array([ 91, 106, 102], dtype=uint8),
#  array([ 90, 106, 102], dtype=uint8),
#  array([ 89, 106, 102], dtype=uint8),
#  array([ 89, 106, 102], dtype=uint8),
#  array([ 89, 106, 102], dtype=uint8),
#  array([ 89, 107, 103], dtype=uint8),
#  array([ 90, 108, 105], dtype=uint8),
#  array([ 91, 109, 105], dtype=uint8),
#  array([ 95, 112, 104], dtype=uint8),
#  array([ 92, 111, 107], dtype=uint8),
#  array([ 89, 109, 106], dtype=uint8),
#  array([ 87, 109, 103], dtype=uint8),
#  array([ 87, 110, 102], dtype=uint8),
#  array([ 89, 111, 105], dtype=uint8),
#  array([ 93, 109, 104], dtype=uint8),
#  array([ 95, 108, 101], dtype=uint8),
#  array([ 96, 106, 102], dtype=uint8),
#  array([ 86, 104, 101], dtype=uint8),
#  array([ 80, 103,  99], dtype=uint8),
#  array([ 84, 104,  98], dtype=uint8),
#  array([ 87, 107,  99], dtype=uint8),
#  array([ 88, 110, 102], dtype=uint8),
#  array([ 92, 111, 106], dtype=uint8),
#  array([ 98, 111, 108], dtype=uint8),
#  array([ 88, 107, 104], dtype=uint8),
#  array([ 88, 108, 105], dtype=uint8),
#  array([ 88, 108, 105], dtype=uint8),
#  array([ 87, 108, 105], dtype=uint8),
#  array([ 87, 106, 103], dtype=uint8),
#  array([ 88, 105, 103], dtype=uint8),
#  array([ 91, 106, 104], dtype=uint8),
#  array([ 93, 107, 104], dtype=uint8),
#  array([ 87, 103, 101], dtype=uint8),
#  array([ 87, 104, 100], dtype=uint8),
#  array([ 87, 105, 100], dtype=uint8),
#  array([ 91, 106, 100], dtype=uint8),
#  array([ 94, 108, 100], dtype=uint8),
#  array([ 95, 109, 101], dtype=uint8),
#  array([ 92, 110, 102], dtype=uint8),
#  array([ 88, 110, 103], dtype=uint8),
#  array([ 91, 106, 105], dtype=uint8),
#  array([ 94, 110, 106], dtype=uint8),
#  array([ 92, 114, 105], dtype=uint8),
#  array([ 87, 112, 103], dtype=uint8),
#  array([ 88, 107, 101], dtype=uint8),
#  array([ 94, 105, 100], dtype=uint8),
#  array([ 97, 107, 101], dtype=uint8),
#  array([ 94, 111, 102], dtype=uint8),
#  array([ 96, 112, 103], dtype=uint8),
#  array([ 93, 110, 104], dtype=uint8),
#  array([ 91, 107, 104], dtype=uint8),
#  array([ 90, 107, 104], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 95, 111, 103], dtype=uint8),
#  array([ 97, 112, 105], dtype=uint8),
#  array([ 97, 111, 106], dtype=uint8),
#  array([ 86, 110, 103], dtype=uint8),
#  array([ 88, 110, 103], dtype=uint8),
#  array([ 90, 110, 103], dtype=uint8),
#  array([ 90, 109, 103], dtype=uint8),
#  array([ 89, 109, 103], dtype=uint8),
#  array([ 89, 109, 105], dtype=uint8),
#  array([ 93, 108, 106], dtype=uint8),
#  array([ 96, 108, 107], dtype=uint8),
#  array([ 95, 108, 106], dtype=uint8),
#  array([ 95, 106, 106], dtype=uint8),
#  array([ 93, 106, 106], dtype=uint8),
#  array([ 90, 107, 104], dtype=uint8),
#  array([ 93, 109, 102], dtype=uint8),
#  array([ 96, 111, 101], dtype=uint8),
#  array([ 94, 112, 102], dtype=uint8),
#  array([ 89, 112, 104], dtype=uint8),
#  array([ 94, 112, 104], dtype=uint8),
#  array([ 87, 110, 104], dtype=uint8),
#  array([ 84, 107, 104], dtype=uint8),
#  array([ 88, 106, 103], dtype=uint8),
#  array([ 89, 107, 103], dtype=uint8),
#  array([ 86, 108, 102], dtype=uint8),
#  array([ 86, 108, 102], dtype=uint8),
#  array([ 90, 107, 102], dtype=uint8),
#  array([ 92, 112, 104], dtype=uint8),
#  array([ 91, 112, 104], dtype=uint8),
#  array([ 87, 110, 103], dtype=uint8),
#  array([ 83, 108, 101], dtype=uint8),
#  array([ 81, 106, 101], dtype=uint8),
#  array([ 83, 106, 101], dtype=uint8),
#  array([ 88, 109, 101], dtype=uint8),
#  array([ 92, 111, 101], dtype=uint8),
#  array([ 84, 110, 100], dtype=uint8),
#  array([ 88, 108, 101], dtype=uint8),
#  array([ 92, 107, 103], dtype=uint8),
#  array([ 92, 107, 104], dtype=uint8),
#  array([ 91, 109, 104], dtype=uint8),
#  array([ 91, 111, 103], dtype=uint8),
#  array([ 93, 110, 101], dtype=uint8),
#  array([ 96, 110, 100], dtype=uint8),
#  array([ 91, 110,  97], dtype=uint8),
#  array([ 93, 111, 100], dtype=uint8),
#  array([ 94, 112, 102], dtype=uint8),
#  array([ 94, 110, 102], dtype=uint8),
#  array([ 92, 108, 101], dtype=uint8),
#  array([ 91, 106, 101], dtype=uint8),
#  array([ 91, 107, 102], dtype=uint8),
#  array([ 92, 108, 103], dtype=uint8),
#  array([ 80, 105,  97], dtype=uint8),
#  array([ 82, 104,  97], dtype=uint8),
#  array([ 86, 105, 100], dtype=uint8),
#  array([ 92, 109, 105], dtype=uint8),
#  array([ 97, 112, 109], dtype=uint8),
#  array([ 97, 113, 110], dtype=uint8),
#  array([ 92, 110, 106], dtype=uint8),
#  array([ 87, 106, 101], dtype=uint8),
#  array([ 86, 112, 102], dtype=uint8),
#  array([ 92, 109, 102], dtype=uint8),
#  array([ 96, 107, 102], dtype=uint8),
#  array([ 94, 106, 101], dtype=uint8),
#  array([ 87, 106, 101], dtype=uint8),
#  array([ 83, 106, 100], dtype=uint8),
#  array([ 85, 105, 100], dtype=uint8),
#  array([ 89, 104, 100], dtype=uint8),
#  array([ 93, 113, 103], dtype=uint8),
#  array([ 93, 113, 104], dtype=uint8),
#  array([ 93, 113, 104], dtype=uint8),
#  array([ 93, 113, 105], dtype=uint8),
#  array([ 92, 113, 105], dtype=uint8),
#  array([ 91, 112, 104], dtype=uint8),
#  array([ 90, 111, 104], dtype=uint8),
#  array([ 90, 110, 103], dtype=uint8),
#  array([ 85, 106,  97], dtype=uint8),
#  array([ 83, 105,  98], dtype=uint8),
#  array([ 83, 104,  99], dtype=uint8),
#  array([ 87, 106, 101], dtype=uint8),
#  array([ 93, 110, 103], dtype=uint8),
#  array([ 97, 112, 103], dtype=uint8),
#  array([ 97, 111, 103], dtype=uint8),
#  array([ 95, 109, 103], dtype=uint8),
#  array([ 94, 109, 102], dtype=uint8),
#  array([ 92, 109, 100], dtype=uint8),
#  array([ 92, 110, 100], dtype=uint8),
#  array([ 96, 112, 103], dtype=uint8),
#  array([101, 115, 107], dtype=uint8),
#  array([103, 114, 108], dtype=uint8),
#  array([ 99, 112, 104], dtype=uint8),
#  array([ 95, 109,  99], dtype=uint8),
#  array([ 95, 111, 104], dtype=uint8),
#  array([ 97, 111, 104], dtype=uint8),
#  array([ 99, 110, 103], dtype=uint8),
#  array([ 98, 109, 102], dtype=uint8),
#  array([ 95, 108, 102], dtype=uint8),
#  array([ 93, 107, 102], dtype=uint8),
#  array([ 93, 106, 102], dtype=uint8),
#  array([ 95, 106, 102], dtype=uint8),
#  array([ 98, 111, 104], dtype=uint8),
#  array([ 97, 111, 104], dtype=uint8),
#  array([ 93, 110, 103], dtype=uint8),
#  array([ 89, 110, 102], dtype=uint8),
#  array([ 91, 109, 101], dtype=uint8),
#  array([ 93, 108, 100], dtype=uint8),
#  array([ 88, 107, 100], dtype=uint8),
#  array([ 81, 106, 100], dtype=uint8),
#  array([ 85, 102, 100], dtype=uint8),
#  array([ 88, 107, 102], dtype=uint8),
#  array([ 95, 114, 105], dtype=uint8),
#  array([103, 118, 107], dtype=uint8),
#  array([108, 118, 108], dtype=uint8),
#  array([107, 115, 107], dtype=uint8),
#  array([100, 112, 105], dtype=uint8),
#  array([ 94, 110, 104], dtype=uint8),
#  array([ 95, 110, 108], dtype=uint8),
#  array([ 93, 111, 103], dtype=uint8),
#  array([ 95, 112, 103], dtype=uint8),
#  array([ 99, 113, 107], dtype=uint8),
#  array([ 98, 113, 109], dtype=uint8),
#  array([ 93, 112, 105], dtype=uint8),
#  array([ 90, 111, 100], dtype=uint8),
#  array([ 91, 110, 100], dtype=uint8),
#  array([ 90, 110, 104], dtype=uint8),
#  array([ 89, 111, 104], dtype=uint8),
#  array([ 91, 113, 105], dtype=uint8),
#  array([ 94, 113, 105], dtype=uint8),
#  array([ 92, 113, 105], dtype=uint8),
#  array([ 88, 111, 105], dtype=uint8),
#  array([ 89, 109, 104], dtype=uint8),
#  array([ 93, 107, 103], dtype=uint8),
#  array([ 90, 109, 101], dtype=uint8),
#  array([ 90, 111, 105], dtype=uint8),
#  array([ 94, 113, 108], dtype=uint8),
#  array([ 98, 113, 107], dtype=uint8),
#  array([ 96, 112, 103], dtype=uint8),
#  array([ 91, 111, 100], dtype=uint8),
#  array([ 91, 111, 102], dtype=uint8),
#  array([ 95, 112, 105], dtype=uint8),
#  array([ 93, 111, 103], dtype=uint8),
#  array([ 92, 109, 103], dtype=uint8),
#  array([ 91, 108, 104], dtype=uint8),
#  array([ 91, 108, 104], dtype=uint8),
#  array([ 90, 110, 104], dtype=uint8),
#  array([ 90, 110, 103], dtype=uint8),
#  array([ 90, 109, 102], dtype=uint8),
#  array([ 90, 107, 101], dtype=uint8),
#  array([ 95, 112, 104], dtype=uint8),
#  array([ 96, 111, 105], dtype=uint8),
#  array([ 95, 109, 104], dtype=uint8),
#  array([ 93, 108, 103], dtype=uint8),
#  array([ 91, 108, 101], dtype=uint8),
#  array([ 90, 109, 102], dtype=uint8),
#  array([ 92, 111, 104], dtype=uint8),
#  array([ 94, 112, 107], dtype=uint8),
#  array([ 97, 114, 108], dtype=uint8),
#  array([ 97, 114, 107], dtype=uint8),
#  array([ 97, 113, 105], dtype=uint8),
#  array([ 98, 112, 104], dtype=uint8),
#  array([ 98, 111, 103], dtype=uint8),
#  array([ 97, 111, 104], dtype=uint8),
#  array([ 97, 111, 105], dtype=uint8),
#  array([ 96, 111, 105], dtype=uint8),
#  array([ 91, 107, 101], dtype=uint8),
#  array([ 90, 109, 103], dtype=uint8),
#  array([ 89, 110, 104], dtype=uint8),
#  array([ 90, 110, 104], dtype=uint8),
#  array([ 92, 110, 103], dtype=uint8),
#  array([ 94, 110, 103], dtype=uint8),
#  array([ 97, 111, 104], dtype=uint8),
#  array([ 99, 113, 106], dtype=uint8),
#  array([ 96, 110, 103], dtype=uint8),
#  array([ 95, 111, 105], dtype=uint8),
#  array([ 96, 112, 106], dtype=uint8),
#  array([ 98, 114, 105], dtype=uint8),
#  array([101, 114, 104], dtype=uint8),
#  array([101, 114, 103], dtype=uint8),
#  array([ 98, 113, 104], dtype=uint8),
#  array([ 95, 112, 106], dtype=uint8),
#  array([ 91, 111, 104], dtype=uint8),
#  array([ 94, 110, 103], dtype=uint8),
#  array([ 96, 109, 102], dtype=uint8),
#  array([ 94, 108, 101], dtype=uint8),
#  array([ 90, 108, 102], dtype=uint8),
#  array([ 89, 108, 103], dtype=uint8),
#  array([ 93, 108, 105], dtype=uint8),
#  array([ 97, 109, 106], dtype=uint8),
#  array([ 93, 107, 102], dtype=uint8),
#  array([ 92, 108, 101], dtype=uint8),
#  array([ 92, 110, 101], dtype=uint8),
#  array([ 95, 112, 103], dtype=uint8),
#  array([ 98, 113, 106], dtype=uint8),
#  array([100, 114, 109], dtype=uint8),
#  array([100, 114, 109], dtype=uint8),
#  array([100, 114, 108], dtype=uint8),
#  array([ 91, 110, 104], dtype=uint8),
#  array([ 92, 107, 104], dtype=uint8),
#  array([ 91, 106, 104], dtype=uint8),
#  array([ 88, 106, 104], dtype=uint8),
#  array([ 90, 109, 104], dtype=uint8),
#  array([ 94, 111, 104], dtype=uint8),
#  array([ 93, 112, 104], dtype=uint8),
#  array([ 89, 112, 104], dtype=uint8),
#  array([ 91, 107, 103], dtype=uint8),
#  array([ 91, 107, 102], dtype=uint8),
#  array([ 90, 107, 102], dtype=uint8),
#  array([ 90, 107, 102], dtype=uint8),
#  array([ 90, 107, 103], dtype=uint8),
#  array([ 90, 108, 103], dtype=uint8),
#  array([ 91, 109, 104], dtype=uint8),
#  array([ 91, 110, 105], dtype=uint8),
#  array([ 94, 113, 105], dtype=uint8),
#  array([ 92, 111, 108], dtype=uint8),
#  array([ 90, 110, 107], dtype=uint8),
#  array([ 89, 110, 104], dtype=uint8),
#  array([ 89, 111, 103], dtype=uint8),
#  array([ 90, 111, 106], dtype=uint8),
#  array([ 93, 110, 106], dtype=uint8),
#  array([ 94, 108, 102], dtype=uint8),
#  array([ 94, 105, 104], dtype=uint8),
#  array([ 86, 104, 103], dtype=uint8),
#  array([ 81, 103, 101], dtype=uint8),
#  array([ 85, 104,  99], dtype=uint8),
#  array([ 88, 107,  99], dtype=uint8),
#  array([ 89, 111, 101], dtype=uint8),
#  array([ 93, 112, 104], dtype=uint8),
#  array([ 97, 112, 106], dtype=uint8),
#  array([ 88, 109, 103], dtype=uint8),
#  array([ 88, 109, 104], dtype=uint8),
#  array([ 88, 109, 105], dtype=uint8),
#  array([ 88, 108, 104], dtype=uint8),
#  array([ 88, 107, 103], dtype=uint8),
#  array([ 90, 106, 103], dtype=uint8),
#  array([ 92, 106, 104], dtype=uint8),
#  array([ 94, 106, 104], dtype=uint8),
#  array([ 87, 105, 102], dtype=uint8),
#  array([ 86, 106, 102], dtype=uint8),
#  array([ 86, 107, 101], dtype=uint8),
#  array([ 89, 108, 101], dtype=uint8),
#  array([ 92, 109, 102], dtype=uint8),
#  array([ 93, 111, 103], dtype=uint8),
#  array([ 91, 112, 103], dtype=uint8),
#  array([ 88, 112, 104], dtype=uint8),
#  array([ 91, 107, 105], dtype=uint8),
#  array([ 94, 111, 106], dtype=uint8),
#  array([ 93, 114, 106], dtype=uint8),
#  array([ 89, 112, 104], dtype=uint8),
#  array([ 89, 107, 101], dtype=uint8),
#  array([ 94, 105, 101], dtype=uint8),
#  array([ 95, 107, 102], dtype=uint8),
#  array([ 92, 110, 103], dtype=uint8),
#  array([ 94, 113, 104], dtype=uint8),
#  array([ 93, 111, 104], dtype=uint8),
#  array([ 92, 109, 105], dtype=uint8),
#  array([ 93, 109, 104], dtype=uint8),
#  array([ 96, 111, 104], dtype=uint8),
#  array([ 99, 113, 105], dtype=uint8),
#  array([ 99, 113, 107], dtype=uint8),
#  array([ 99, 112, 108], dtype=uint8),
#  array([ 89, 109, 104], dtype=uint8),
#  array([ 91, 109, 104], dtype=uint8),
#  array([ 93, 110, 104], dtype=uint8),
#  array([ 92, 110, 104], dtype=uint8),
#  array([ 90, 109, 104], dtype=uint8),
#  array([ 89, 108, 104], dtype=uint8),
#  array([ 90, 107, 103], dtype=uint8),
#  array([ 92, 106, 103], dtype=uint8),
#  array([ 92, 107, 103], dtype=uint8),
#  array([ 94, 107, 104], dtype=uint8),
#  array([ 94, 106, 104], dtype=uint8),
#  array([ 91, 107, 103], dtype=uint8),
#  array([ 91, 109, 101], dtype=uint8),
#  array([ 95, 111, 101], dtype=uint8),
#  array([ 95, 112, 102], dtype=uint8),
#  array([ 92, 112, 104], dtype=uint8),
#  array([ 95, 112, 104], dtype=uint8),
#  array([ 88, 109, 104], dtype=uint8),
#  array([ 84, 107, 104], dtype=uint8),
#  array([ 87, 106, 103], dtype=uint8),
#  array([ 88, 107, 103], dtype=uint8),
#  array([ 86, 108, 102], dtype=uint8),
#  array([ 87, 108, 102], dtype=uint8),
#  array([ 90, 107, 102], dtype=uint8),
#  array([ 92, 110, 104], dtype=uint8),
#  array([ 91, 110, 103], dtype=uint8),
#  array([ 88, 109, 102], dtype=uint8),
#  array([ 85, 107, 101], dtype=uint8),
#  array([ 83, 105, 101], dtype=uint8),
#  array([ 84, 106, 101], dtype=uint8),
#  array([ 88, 109, 102], dtype=uint8),
#  array([ 92, 111, 102], dtype=uint8),
#  array([ 88, 110, 101], dtype=uint8),
#  array([ 91, 108, 102], dtype=uint8),
#  array([ 94, 107, 102], dtype=uint8),
#  array([ 94, 107, 103], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 93, 111, 102], dtype=uint8),
#  array([ 95, 110, 102], dtype=uint8),
#  array([ 97, 110, 101], dtype=uint8),
#  array([ 89, 110,  98], dtype=uint8),
#  array([ 91, 111, 100], dtype=uint8),
#  array([ 92, 112, 102], dtype=uint8),
#  array([ 92, 110, 102], dtype=uint8),
#  array([ 90, 108, 101], dtype=uint8),
#  array([ 88, 106, 100], dtype=uint8),
#  array([ 89, 107, 101], dtype=uint8),
#  array([ 89, 108, 102], dtype=uint8),
#  array([ 83, 106,  99], dtype=uint8),
#  array([ 83, 105,  99], dtype=uint8),
#  array([ 86, 105, 100], dtype=uint8),
#  array([ 90, 108, 104], dtype=uint8),
#  array([ 94, 111, 107], dtype=uint8),
#  array([ 95, 112, 108], dtype=uint8),
#  array([ 92, 110, 105], dtype=uint8),
#  array([ 89, 107, 102], dtype=uint8),
#  array([ 88, 111, 102], dtype=uint8),
#  array([ 92, 110, 102], dtype=uint8),
#  array([ 95, 108, 101], dtype=uint8),
#  array([ 93, 107, 101], dtype=uint8),
#  array([ 89, 108, 101], dtype=uint8),
#  array([ 86, 108, 100], dtype=uint8),
#  array([ 86, 106, 100], dtype=uint8),
#  array([ 89, 104, 100], dtype=uint8),
#  array([ 93, 111, 103], dtype=uint8),
#  array([ 94, 112, 104], dtype=uint8),
#  array([ 94, 112, 104], dtype=uint8),
#  array([ 95, 112, 104], dtype=uint8),
#  array([ 95, 112, 104], dtype=uint8),
#  array([ 94, 111, 104], dtype=uint8),
#  array([ 92, 110, 104], dtype=uint8),
#  array([ 92, 110, 103], dtype=uint8),
#  array([ 86, 107,  99], dtype=uint8),
#  array([ 85, 105,  99], dtype=uint8),
#  array([ 85, 103, 100], dtype=uint8),
#  array([ 88, 105, 101], dtype=uint8),
#  array([ 92, 108, 102], dtype=uint8),
#  array([ 95, 110, 102], dtype=uint8),
#  array([ 95, 109, 103], dtype=uint8),
#  array([ 94, 108, 103], dtype=uint8),
#  array([ 90, 106, 100], dtype=uint8),
#  array([ 89, 106,  99], dtype=uint8),
#  array([ 90, 108,  99], dtype=uint8),
#  array([ 94, 110, 103], dtype=uint8),
#  array([ 99, 113, 107], dtype=uint8),
#  array([102, 114, 108], dtype=uint8),
#  array([ 99, 113, 106], dtype=uint8),
#  array([ 96, 111, 102], dtype=uint8),
#  array([ 93, 108, 103], dtype=uint8),
#  array([ 94, 108, 103], dtype=uint8),
#  array([ 95, 109, 103], dtype=uint8),
#  array([ 94, 109, 102], dtype=uint8),
#  array([ 92, 109, 102], dtype=uint8),
#  array([ 90, 107, 101], dtype=uint8),
#  array([ 89, 106, 101], dtype=uint8),
#  array([ 90, 104, 101], dtype=uint8),
#  array([ 96, 110, 105], dtype=uint8),
#  array([ 98, 110, 104], dtype=uint8),
#  array([ 98, 110, 104], dtype=uint8),
#  array([ 93, 110, 103], dtype=uint8),
#  array([ 92, 109, 102], dtype=uint8),
#  array([ 93, 108, 102], dtype=uint8),
#  array([ 91, 107, 101], dtype=uint8),
#  array([ 86, 106, 101], dtype=uint8),
#  array([ 87, 103, 101], dtype=uint8),
#  array([ 87, 105, 100], dtype=uint8),
#  array([ 90, 109, 100], dtype=uint8),
#  array([ 98, 113, 103], dtype=uint8),
#  array([106, 117, 108], dtype=uint8),
#  array([108, 117, 110], dtype=uint8),
#  array([103, 115, 109], dtype=uint8),
#  array([ 97, 113, 106], dtype=uint8),
#  array([ 92, 110, 106], dtype=uint8),
#  array([ 89, 110, 103], dtype=uint8),
#  array([ 90, 110, 102], dtype=uint8),
#  array([ 94, 110, 106], dtype=uint8),
#  array([ 94, 110, 107], dtype=uint8),
#  array([ 90, 110, 103], dtype=uint8),
#  array([ 89, 110, 100], dtype=uint8),
#  array([ 91, 110, 100], dtype=uint8),
#  array([ 90, 109, 104], dtype=uint8),
#  array([ 89, 110, 104], dtype=uint8),
#  array([ 91, 112, 105], dtype=uint8),
#  array([ 95, 112, 106], dtype=uint8),
#  array([ 94, 112, 106], dtype=uint8),
#  array([ 91, 111, 106], dtype=uint8),
#  array([ 92, 109, 105], dtype=uint8),
#  array([ 96, 108, 105], dtype=uint8),
#  array([ 90, 109, 102], dtype=uint8),
#  array([ 91, 112, 105], dtype=uint8),
#  array([ 94, 115, 108], dtype=uint8),
#  array([ 98, 115, 107], dtype=uint8),
#  array([ 96, 113, 103], dtype=uint8),
#  array([ 90, 111, 101], dtype=uint8),
#  array([ 89, 110, 102], dtype=uint8),
#  array([ 91, 110, 104], dtype=uint8),
#  array([ 92, 108, 101], dtype=uint8),
#  array([ 92, 107, 102], dtype=uint8),
#  array([ 91, 108, 103], dtype=uint8),
#  array([ 91, 110, 104], dtype=uint8),
#  array([ 91, 112, 104], dtype=uint8),
#  array([ 90, 112, 104], dtype=uint8),
#  array([ 90, 110, 104], dtype=uint8),
#  array([ 90, 107, 104], dtype=uint8),
#  array([ 93, 110, 102], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 91, 108, 102], dtype=uint8),
#  array([ 90, 109, 102], dtype=uint8),
#  array([ 92, 111, 103], dtype=uint8),
#  array([ 97, 113, 106], dtype=uint8),
#  array([100, 114, 108], dtype=uint8),
#  array([100, 117, 110], dtype=uint8),
#  array([100, 117, 108], dtype=uint8),
#  array([100, 115, 106], dtype=uint8),
#  array([ 99, 114, 104], dtype=uint8),
#  array([ 99, 113, 103], dtype=uint8),
#  array([ 98, 112, 103], dtype=uint8),
#  array([ 98, 112, 104], dtype=uint8),
#  array([ 97, 112, 104], dtype=uint8),
#  array([ 91, 107, 102], dtype=uint8),
#  array([ 91, 108, 104], dtype=uint8),
#  array([ 91, 110, 105], dtype=uint8),
#  array([ 91, 110, 105], dtype=uint8),
#  array([ 93, 110, 104], dtype=uint8),
#  array([ 96, 110, 104], dtype=uint8),
#  array([ 98, 112, 105], dtype=uint8),
#  array([100, 113, 106], dtype=uint8),
#  array([ 94, 110, 102], dtype=uint8),
#  array([ 94, 110, 104], dtype=uint8),
#  array([ 95, 111, 105], dtype=uint8),
#  array([ 98, 111, 104], dtype=uint8),
#  array([ 99, 111, 103], dtype=uint8),
#  array([ 99, 112, 102], dtype=uint8),
#  array([ 96, 112, 103], dtype=uint8),
#  array([ 94, 112, 105], dtype=uint8),
#  array([ 91, 111, 104], dtype=uint8),
#  array([ 93, 110, 103], dtype=uint8),
#  array([ 95, 109, 102], dtype=uint8),
#  array([ 93, 108, 101], dtype=uint8),
#  array([ 90, 108, 102], dtype=uint8),
#  array([ 90, 108, 103], dtype=uint8),
#  array([ 92, 108, 105], dtype=uint8),
#  array([ 96, 109, 106], dtype=uint8),
#  array([ 92, 108, 103], dtype=uint8),
#  array([ 91, 108, 101], dtype=uint8),
#  array([ 91, 109, 100], dtype=uint8),
#  array([ 93, 109, 101], dtype=uint8),
#  array([ 96, 110, 104], dtype=uint8),
#  array([ 98, 112, 107], dtype=uint8),
#  array([ 98, 113, 108], dtype=uint8),
#  array([ 97, 114, 108], dtype=uint8),
#  array([ 93, 110, 104], dtype=uint8),
#  array([ 93, 108, 104], dtype=uint8),
#  array([ 90, 106, 104], dtype=uint8),
#  array([ 86, 106, 104], dtype=uint8),
#  array([ 88, 109, 104], dtype=uint8),
#  array([ 93, 111, 104], dtype=uint8),
#  array([ 93, 112, 104], dtype=uint8),
#  array([ 90, 111, 104], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 92, 109, 103], dtype=uint8),
#  array([ 92, 108, 103], dtype=uint8),
#  array([ 91, 108, 102], dtype=uint8),
#  array([ 91, 108, 103], dtype=uint8),
#  array([ 92, 109, 104], dtype=uint8),
#  array([ 92, 110, 104], dtype=uint8),
#  array([ 93, 111, 105], dtype=uint8),
#  array([ 93, 113, 105], dtype=uint8),
#  array([ 93, 112, 108], dtype=uint8),
#  array([ 92, 110, 108], dtype=uint8),
#  array([ 91, 110, 104], dtype=uint8),
#  array([ 91, 112, 104], dtype=uint8),
#  array([ 92, 112, 107], dtype=uint8),
#  array([ 92, 110, 107], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 90, 105, 106], dtype=uint8),
#  array([ 85, 103, 104], dtype=uint8),
#  array([ 83, 103, 102], dtype=uint8),
#  array([ 86, 104, 100], dtype=uint8),
#  array([ 90, 108, 100], dtype=uint8),
#  array([ 91, 112, 101], dtype=uint8),
#  array([ 93, 114, 102], dtype=uint8),
#  array([ 97, 114, 104], dtype=uint8),
#  array([ 89, 111, 103], dtype=uint8),
#  array([ 89, 111, 103], dtype=uint8),
#  array([ 89, 110, 103], dtype=uint8),
#  array([ 89, 109, 104], dtype=uint8),
#  array([ 90, 108, 104], dtype=uint8),
#  array([ 91, 107, 104], dtype=uint8),
#  array([ 93, 106, 104], dtype=uint8),
#  array([ 93, 106, 104], dtype=uint8),
#  array([ 89, 108, 103], dtype=uint8),
#  array([ 88, 108, 103], dtype=uint8),
#  array([ 87, 109, 102], dtype=uint8),
#  array([ 89, 110, 102], dtype=uint8),
#  array([ 91, 111, 103], dtype=uint8),
#  array([ 92, 112, 103], dtype=uint8),
#  array([ 91, 113, 104], dtype=uint8),
#  array([ 90, 114, 105], dtype=uint8),
#  array([ 90, 109, 106], dtype=uint8),
#  array([ 93, 112, 107], dtype=uint8),
#  array([ 93, 113, 107], dtype=uint8),
#  array([ 91, 111, 105], dtype=uint8),
#  array([ 91, 107, 102], dtype=uint8),
#  array([ 93, 105, 102], dtype=uint8),
#  array([ 92, 106, 103], dtype=uint8),
#  array([ 89, 109, 105], dtype=uint8),
#  array([ 92, 113, 104], dtype=uint8),
#  array([ 92, 111, 104], dtype=uint8),
#  array([ 93, 109, 104], dtype=uint8),
#  array([ 96, 110, 104], dtype=uint8),
#  array([ 99, 112, 106], dtype=uint8),
#  array([101, 113, 107], dtype=uint8),
#  array([101, 113, 108], dtype=uint8),
#  array([100, 113, 109], dtype=uint8),
#  array([ 90, 108, 104], dtype=uint8),
#  array([ 92, 109, 105], dtype=uint8),
#  array([ 94, 110, 105], dtype=uint8),
#  array([ 93, 110, 106], dtype=uint8),
#  array([ 91, 109, 105], dtype=uint8),
#  array([ 88, 107, 103], dtype=uint8),
#  array([ 87, 104, 101], dtype=uint8),
#  array([ 87, 103, 100], dtype=uint8),
#  array([ 88, 107, 101], dtype=uint8),
#  array([ 93, 107, 102], dtype=uint8),
#  array([ 95, 107, 102], dtype=uint8),
#  array([ 91, 108, 102], dtype=uint8),
#  array([ 89, 109, 100], dtype=uint8),
#  array([ 92, 110, 101], dtype=uint8),
#  array([ 96, 112, 103], dtype=uint8),
#  array([ 96, 113, 105], dtype=uint8),
#  array([ 95, 112, 104], dtype=uint8),
#  array([ 89, 109, 104], dtype=uint8),
#  array([ 85, 106, 103], dtype=uint8),
#  array([ 86, 106, 103], dtype=uint8),
#  array([ 87, 107, 103], dtype=uint8),
#  array([ 87, 108, 103], dtype=uint8),
#  array([ 88, 108, 102], dtype=uint8),
#  array([ 91, 108, 102], dtype=uint8),
#  array([ 91, 108, 103], dtype=uint8),
#  array([ 91, 108, 102], dtype=uint8),
#  array([ 89, 108, 102], dtype=uint8),
#  array([ 87, 106, 101], dtype=uint8),
#  array([ 85, 104, 102], dtype=uint8),
#  array([ 86, 105, 102], dtype=uint8),
#  array([ 89, 109, 103], dtype=uint8),
#  array([ 91, 112, 104], dtype=uint8),
#  array([ 90, 110, 103], dtype=uint8),
#  array([ 92, 108, 102], dtype=uint8),
#  array([ 93, 107, 102], dtype=uint8),
#  array([ 93, 107, 101], dtype=uint8),
#  array([ 92, 109, 101], dtype=uint8),
#  array([ 92, 111, 102], dtype=uint8),
#  array([ 94, 110, 102], dtype=uint8),
#  array([ 95, 110, 103], dtype=uint8),
#  array([ 89, 110, 100], dtype=uint8),
#  array([ 91, 111, 102], dtype=uint8),
#  array([ 92, 112, 104], dtype=uint8),
#  array([ 92, 110, 104], dtype=uint8),
#  array([ 90, 108, 103], dtype=uint8),
#  array([ 88, 106, 102], dtype=uint8),
#  array([ 88, 107, 103], dtype=uint8),
#  array([ 89, 108, 104], dtype=uint8),
#  array([ 87, 108, 102], dtype=uint8),
#  array([ 86, 107, 101], dtype=uint8),
#  array([ 85, 105, 101], dtype=uint8),
#  array([ 87, 106, 102], dtype=uint8),
#  array([ 90, 108, 104], dtype=uint8),
#  array([ 92, 110, 105], dtype=uint8),
#  array([ 92, 110, 104], dtype=uint8),
#  array([ 91, 109, 102], dtype=uint8),
#  array([ 91, 111, 103], dtype=uint8),
#  array([ 92, 110, 102], dtype=uint8),
#  array([ 92, 109, 101], dtype=uint8),
#  array([ 92, 109, 100], dtype=uint8),
#  array([ 91, 110, 100], dtype=uint8),
#  array([ 90, 110, 100], dtype=uint8),
#  array([ 89, 107, 100], dtype=uint8),
#  array([ 89, 105, 101], dtype=uint8),
#  array([ 90, 109, 103], dtype=uint8),
#  array([ 91, 109, 103], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 94, 110, 103], dtype=uint8),
#  array([ 94, 110, 103], dtype=uint8),
#  array([ 93, 110, 103], dtype=uint8),
#  array([ 92, 110, 103], dtype=uint8),
#  array([ 91, 110, 103], dtype=uint8),
#  array([ 89, 109, 102], dtype=uint8),
#  array([ 88, 107, 102], dtype=uint8),
#  array([ 87, 104, 101], dtype=uint8),
#  array([ 89, 104, 101], dtype=uint8),
#  array([ 91, 105, 101], dtype=uint8),
#  array([ 93, 107, 101], dtype=uint8),
#  array([ 92, 107, 102], dtype=uint8),
#  array([ 91, 107, 102], dtype=uint8),
#  array([ 90, 106, 101], dtype=uint8),
#  array([ 90, 106, 100], dtype=uint8),
#  array([ 90, 106, 100], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 97, 112, 106], dtype=uint8),
#  array([ 99, 113, 107], dtype=uint8),
#  array([ 98, 111, 105], dtype=uint8),
#  array([ 96, 110, 103], dtype=uint8),
#  array([ 92, 106, 103], dtype=uint8),
#  array([ 93, 107, 103], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 92, 110, 102], dtype=uint8),
#  array([ 90, 109, 102], dtype=uint8),
#  array([ 88, 107, 101], dtype=uint8),
#  array([ 87, 105, 100], dtype=uint8),
#  array([ 86, 103,  99], dtype=uint8),
#  array([ 93, 109, 105], dtype=uint8),
#  array([ 99, 110, 105], dtype=uint8),
#  array([101, 110, 105], dtype=uint8),
#  array([ 97, 111, 105], dtype=uint8),
#  array([ 93, 110, 104], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 93, 107, 103], dtype=uint8),
#  array([ 91, 106, 102], dtype=uint8),
#  array([ 90, 107, 104], dtype=uint8),
#  array([ 87, 106, 100], dtype=uint8),
#  array([ 88, 106,  98], dtype=uint8),
#  array([ 94, 110, 100], dtype=uint8),
#  array([101, 115, 107], dtype=uint8),
#  array([104, 117, 110], dtype=uint8),
#  array([101, 116, 109], dtype=uint8),
#  array([ 95, 113, 105], dtype=uint8),
#  array([ 88, 108, 103], dtype=uint8),
#  array([ 85, 107, 100], dtype=uint8),
#  array([ 85, 107, 100], dtype=uint8),
#  array([ 88, 106, 104], dtype=uint8),
#  array([ 88, 106, 104], dtype=uint8),
#  array([ 86, 107, 100], dtype=uint8),
#  array([ 87, 107,  98], dtype=uint8),
#  array([ 90, 108, 100], dtype=uint8),
#  array([ 90, 109, 103], dtype=uint8),
#  array([ 89, 109, 104], dtype=uint8),
#  array([ 92, 110, 105], dtype=uint8),
#  array([ 96, 111, 106], dtype=uint8),
#  array([ 96, 111, 106], dtype=uint8),
#  array([ 93, 111, 107], dtype=uint8),
#  array([ 94, 110, 106], dtype=uint8),
#  array([ 99, 110, 106], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 92, 113, 105], dtype=uint8),
#  array([ 95, 116, 107], dtype=uint8),
#  array([ 99, 117, 106], dtype=uint8),
#  array([ 97, 115, 104], dtype=uint8),
#  array([ 91, 111, 102], dtype=uint8),
#  array([ 88, 109, 102], dtype=uint8),
#  array([ 89, 109, 104], dtype=uint8),
#  array([ 91, 107, 101], dtype=uint8),
#  array([ 91, 108, 102], dtype=uint8),
#  array([ 91, 109, 103], dtype=uint8),
#  array([ 92, 111, 104], dtype=uint8),
#  array([ 91, 112, 104], dtype=uint8),
#  array([ 91, 112, 104], dtype=uint8),
#  array([ 91, 108, 103], dtype=uint8),
#  array([ 90, 105, 103], dtype=uint8),
#  array([ 91, 107, 100], dtype=uint8),
#  array([ 91, 106, 101], dtype=uint8),
#  array([ 90, 106, 102], dtype=uint8),
#  array([ 88, 107, 102], dtype=uint8),
#  array([ 89, 108, 101], dtype=uint8),
#  array([ 94, 111, 103], dtype=uint8),
#  array([100, 113, 106], dtype=uint8),
#  array([106, 115, 109], dtype=uint8),
#  array([106, 120, 112], dtype=uint8),
#  array([105, 119, 110], dtype=uint8),
#  array([103, 117, 108], dtype=uint8),
#  array([101, 115, 106], dtype=uint8),
#  array([ 99, 114, 104], dtype=uint8),
#  array([ 97, 113, 104], dtype=uint8),
#  array([ 96, 112, 104], dtype=uint8),
#  array([ 96, 112, 104], dtype=uint8),
#  array([ 92, 107, 104], dtype=uint8),
#  array([ 94, 108, 105], dtype=uint8),
#  array([ 94, 110, 106], dtype=uint8),
#  array([ 92, 110, 106], dtype=uint8),
#  array([ 93, 110, 104], dtype=uint8),
#  array([ 97, 110, 104], dtype=uint8),
#  array([ 99, 112, 105], dtype=uint8),
#  array([ 98, 113, 107], dtype=uint8),
#  array([ 91, 110, 102], dtype=uint8),
#  array([ 93, 110, 104], dtype=uint8),
#  array([ 95, 109, 105], dtype=uint8),
#  array([ 98, 109, 104], dtype=uint8),
#  array([ 98, 109, 103], dtype=uint8),
#  array([ 97, 110, 102], dtype=uint8),
#  array([ 95, 111, 103], dtype=uint8),
#  array([ 93, 112, 105], dtype=uint8),
#  array([ 91, 111, 104], dtype=uint8),
#  array([ 93, 110, 103], dtype=uint8),
#  array([ 94, 109, 102], dtype=uint8),
#  array([ 92, 108, 101], dtype=uint8),
#  array([ 90, 108, 102], dtype=uint8),
#  array([ 90, 108, 103], dtype=uint8),
#  array([ 92, 108, 105], dtype=uint8),
#  array([ 95, 109, 106], dtype=uint8),
#  array([ 92, 109, 105], dtype=uint8),
#  array([ 91, 109, 103], dtype=uint8),
#  array([ 90, 108, 100], dtype=uint8),
#  array([ 92, 108, 100], dtype=uint8),
#  array([ 95, 109, 103], dtype=uint8),
#  array([ 96, 110, 106], dtype=uint8),
#  array([ 96, 113, 108], dtype=uint8),
#  array([ 95, 114, 108], dtype=uint8),
#  array([ 94, 110, 103], dtype=uint8),
#  array([ 93, 108, 103], dtype=uint8),
#  array([ 89, 106, 104], dtype=uint8),
#  array([ 84, 106, 104], dtype=uint8),
#  array([ 86, 108, 104], dtype=uint8),
#  array([ 92, 110, 104], dtype=uint8),
#  array([ 94, 111, 105], dtype=uint8),
#  array([ 91, 111, 105], dtype=uint8),
#  array([ 94, 110, 104], dtype=uint8),
#  array([ 93, 110, 104], dtype=uint8),
#  array([ 93, 109, 103], dtype=uint8),
#  array([ 92, 109, 103], dtype=uint8),
#  array([ 92, 109, 103], dtype=uint8),
#  array([ 93, 110, 104], dtype=uint8),
#  array([ 93, 111, 104], dtype=uint8),
#  array([ 94, 111, 105], dtype=uint8),
#  array([ 93, 114, 104], dtype=uint8),
#  array([ 93, 112, 107], dtype=uint8),
#  array([ 93, 111, 107], dtype=uint8),
#  array([ 93, 111, 103], dtype=uint8),
#  array([ 93, 112, 103], dtype=uint8),
#  array([ 92, 112, 106], dtype=uint8),
#  array([ 91, 111, 106], dtype=uint8),
#  array([ 91, 109, 103], dtype=uint8),
#  array([ 87, 105, 105], dtype=uint8),
#  array([ 85, 104, 104], dtype=uint8),
#  array([ 86, 103, 102], dtype=uint8),
#  array([ 88, 105, 101], dtype=uint8),
#  array([ 90, 109, 101], dtype=uint8),
#  array([ 92, 113, 102], dtype=uint8),
#  array([ 94, 115, 103], dtype=uint8),
#  array([ 96, 115, 105], dtype=uint8),
#  array([ 90, 113, 103], dtype=uint8),
#  array([ 89, 111, 102], dtype=uint8),
#  array([ 89, 110, 102], dtype=uint8),
#  array([ 90, 109, 103], dtype=uint8),
#  array([ 92, 109, 104], dtype=uint8),
#  array([ 93, 108, 105], dtype=uint8),
#  array([ 93, 107, 104], dtype=uint8),
#  array([ 93, 105, 103], dtype=uint8),
#  array([ 91, 108, 102], dtype=uint8),
#  array([ 90, 109, 102], dtype=uint8),
#  array([ 89, 109, 102], dtype=uint8),
#  array([ 90, 110, 102], dtype=uint8),
#  array([ 91, 111, 102], dtype=uint8),
#  array([ 92, 112, 103], dtype=uint8),
#  array([ 93, 113, 104], dtype=uint8),
#  array([ 93, 113, 105], dtype=uint8),
#  array([ 90, 111, 106], dtype=uint8),
#  array([ 92, 112, 107], dtype=uint8),
#  array([ 93, 112, 107], dtype=uint8),
#  array([ 93, 110, 105], dtype=uint8),
#  array([ 93, 107, 103], dtype=uint8),
#  array([ 92, 105, 103], dtype=uint8),
#  array([ 89, 106, 104], dtype=uint8),
#  array([ 87, 108, 106], dtype=uint8),
#  array([ 92, 111, 103], dtype=uint8),
#  array([ 92, 110, 102], dtype=uint8),
#  array([ 94, 109, 102], dtype=uint8),
#  array([ 97, 110, 103], dtype=uint8),
#  array([100, 112, 105], dtype=uint8),
#  array([101, 113, 108], dtype=uint8),
#  array([ 99, 112, 109], dtype=uint8),
#  array([ 96, 111, 109], dtype=uint8),
#  array([ 88, 106, 102], dtype=uint8),
#  array([ 90, 108, 103], dtype=uint8),
#  array([ 91, 110, 105], dtype=uint8),
#  array([ 92, 111, 106], dtype=uint8),
#  array([ 91, 110, 106], dtype=uint8),
#  array([ 88, 107, 104], dtype=uint8),
#  array([ 86, 103, 101], dtype=uint8),
#  array([ 85, 101,  99], dtype=uint8),
#  array([ 84, 106, 100], dtype=uint8),
#  array([ 92, 107, 101], dtype=uint8),
#  array([ 96, 108, 102], dtype=uint8),
#  array([ 92, 108, 102], dtype=uint8),
#  array([ 87, 108, 101], dtype=uint8),
#  array([ 90, 110, 102], dtype=uint8),
#  array([ 96, 112, 104], dtype=uint8),
#  array([100, 114, 107], dtype=uint8),
#  array([ 95, 111, 103], dtype=uint8),
#  array([ 90, 109, 103], dtype=uint8),
#  array([ 86, 106, 103], dtype=uint8),
#  array([ 85, 106, 103], dtype=uint8),
#  array([ 86, 107, 103], dtype=uint8),
#  array([ 88, 109, 103], dtype=uint8),
#  array([ 89, 109, 103], dtype=uint8),
#  array([ 91, 108, 103], dtype=uint8),
#  array([ 89, 107, 102], dtype=uint8),
#  array([ 89, 107, 102], dtype=uint8),
#  array([ 89, 106, 102], dtype=uint8),
#  array([ 87, 105, 102], dtype=uint8),
#  array([ 86, 104, 102], dtype=uint8),
#  array([ 86, 105, 103], dtype=uint8),
#  array([ 88, 109, 104], dtype=uint8),
#  array([ 91, 112, 105], dtype=uint8),
#  array([ 90, 110, 104], dtype=uint8),
#  array([ 90, 108, 103], dtype=uint8),
#  array([ 90, 107, 101], dtype=uint8),
#  array([ 90, 107, 100], dtype=uint8),
#  array([ 89, 109, 100], dtype=uint8),
#  array([ 90, 111, 101], dtype=uint8),
#  array([ 91, 110, 103], dtype=uint8),
#  array([ 91, 110, 104], dtype=uint8),
#  array([ 92, 110, 103], dtype=uint8),
#  array([ 94, 111, 105], dtype=uint8),
#  array([ 95, 112, 107], dtype=uint8),
#  array([ 94, 110, 107], dtype=uint8),
#  array([ 92, 108, 106], dtype=uint8),
#  array([ 90, 106, 105], dtype=uint8),
#  array([ 90, 107, 105], dtype=uint8),
#  array([ 91, 108, 106], dtype=uint8),
#  array([ 90, 110, 105], dtype=uint8),
#  array([ 88, 108, 104], dtype=uint8),
#  array([ 85, 106, 102], dtype=uint8),
#  array([ 84, 105, 100], dtype=uint8),
#  array([ 85, 106, 100], dtype=uint8),
#  array([ 88, 108, 101], dtype=uint8),
#  array([ 91, 109, 102], dtype=uint8),
#  array([ 93, 110, 103], dtype=uint8),
#  ...]

# %%
img_test3=np.asarray(img_test3).reshape(256,256,3)

# %%
img_test4 = [np.reshape(cv2.resize(img_test3,(64,64),interpolation=cv2.INTER_AREA), [1,64,64,3]) ]

# %%
b= model.predict(images)
b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-4cb513cbd254> in <module>()
# ----> 1 b= model.predict(images)
#       2 b
#
# /anaconda2/lib/python2.7/site-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#     911         if not self.built:
#     912             self.build()
# --> 913         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     914
#     915     def predict_on_batch(self, x):
#
# /anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose, steps)
#    1693         x = _standardize_input_data(x, self._feed_input_names,
#    1694                                     self._feed_input_shapes,
# -> 1695                                     check_batch_axis=False)
#    1696         if self.stateful:
#    1697             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# /anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     142                             ' to have shape ' + str(shapes[i]) +
#     143                             ' but got array with shape ' +
# --> 144                             str(array.shape))
#     145     return arrays
#     146
#
# ValueError: Error when checking : expected conv2d_53_input to have shape (None, 64, 64, 3) but got array with shape (300, 256, 256, 3)
